# %% [markdown]
# # **NAIVE-BAYES**

# %% [markdown]
# ## **Pengertian**
#
# Algoritma Naive Bayes adalah algoritma yang mempelajari probabilitas suatu objek dengan ciri-ciri tertentu yang termasuk dalam kelompok atau kelas tertentu.

# %% [markdown]
# ## **Algoritma**
#
# Tahapan dari proses algoritma Naive Bayes adalah:
# 1. Menghitung jumlah kelas / label,
# 2. Menghitung Jumlah Kasus Per Kelas,
# 3. Kalikan Semua Variable Kelas,
# 4. Bandingkan Hasil Per Kelas.

# %% [markdown]
# ## **Implementasi Code**

# %% [markdown]
# import modul

# %%
from sklearn.model_selection import train_test_split #split dataset into train and test data

# %%
import pandas as pd
import numpy as np

# %%
# library for Naive Bayes Gaussian
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer, accuracy_score,precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score,recall_score,f1_score
from sklearn.preprocessing import LabelEncoder

#Model Select
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning, append=True)

# %% [markdown]
# mengambil dataset iris pada github

# %%
dataset_url = "https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv"

# %% [markdown]
# menampilkan 5 data teratas dari dataset

# %%
df = pd.read_csv(dataset_url)
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# melihat baris (banyak data) dan kolom (banyak atribut/fitur)

# %%
#check number of rows and columns in dataset
df.shape
# Out:
# (150, 5)

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X=iris.data
y=iris.target

# %% [markdown]
# menampilkan dataframe tanpa label dari setiap data

# %%
#create a dataframe with all training data except the target column
X = df.drop(columns=["variety"])#check that the target variable has been removed
X.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# Menentukan jumlah data tes/uji yang akan diambil (dalam bentuk persen). Data uji yang akan diambil sebanyak 30%

# %%
# percent_amount_of_test_data = / HUNDRED_PERCENT
percent_amount_of_test_data = 0.3

# %% [markdown]
# Melakukan Train Test Split untuk membagi dataset menjadi training set (data latih) dan test set (data uji/tes).

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = percent_amount_of_test_data, random_state=0)

# %%
# data latih (nilai data)
X_train 

# data tes (nilai data)
X_test 

# data latih (kelas data)
y_train

# data tes (kelas data)
y_test
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 1, 1, 1, 2, 0, 2, 0,
#        0])

# %%
#Mengaktifkan/memanggil/membuat fungsi klasifikasi Naive bayes
gaussian = GaussianNB()
# Memasukkan data training pada fungsi klasifikasi naive bayes
gaussian.fit(X_train, y_train)
#Menentukan hasil prediksi dari x_test
Y_pred = gaussian.predict(X_test) 

accuracy_nb=round(accuracy_score(y_test,Y_pred)* 100, 2)
acc_gaussian = round(gaussian.score(X_train, y_train) * 100, 2)

#melakukan confussion matrix 
cm = confusion_matrix(y_test, Y_pred)

#melihat nilai akurasi, presisi, dan recall dari algoritma naive bayes 
accuracy = accuracy_score(y_test,Y_pred)
precision =precision_score(y_test, Y_pred,average='micro')
recall =  recall_score(y_test, Y_pred,average='micro')
f1 = f1_score(y_test,Y_pred,average='micro')
print('Confusion matrix for Naive Bayes\n',cm)
print('accuracy_Naive Bayes: %.3f' %accuracy)
print('precision_Naive Bayes: %.3f' %precision)
print('recall_Naive Bayes: %.3f' %recall)
print('f1-score_random_Forest : %.3f' %f1)
# Out:
# Confusion matrix for Naive Bayes
#  [[16  0  0]
#  [ 0 18  0]
#  [ 0  0 11]]
# accuracy_Naive Bayes: 1.000
# precision_Naive Bayes: 1.000
# recall_Naive Bayes: 1.000
# f1-score_random_Forest : 1.000

# %%
# separate target 

# values
X=df.iloc[:,0:4].values

# classes
y=df.iloc[:,4].values

# %%
clf = GaussianNB()
clf.fit(X, y)
clf_pf = GaussianNB()
clf_pf.partial_fit(X, y, np.unique(y))
# Out:
# GaussianNB()

# %% [markdown]
# pengujian data uji

# %%
# try with value [5.5, 3, 5, 2.2]
print(clf_pf.predict([[5.5, 3, 5, 2.2]]))
# Out:
# ['Virginica']

# %%
# try with value [4, 3, 5, 1.2]
print(clf_pf.predict([[4, 3, 5, 1.2]]))
# Out:
# ['Versicolor']
